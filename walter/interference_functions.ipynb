# %%
# %matplotlib notebook

# %%
# %run iff_helpers

# %% [markdown]
# ## Infinite lattices

# %%
plot_infinite_lattice(1., 20., unit)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ## Finite lattices

# %%
plot_finite_lattice(1., 4, unit)
# Out:
# <img src="data:image/png;base64,..." width="1000">
