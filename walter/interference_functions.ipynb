# %%
# %matplotlib notebook

# %%
# %run iff_helpers

# %% [markdown]
# ## Infinite lattices

# %%
plot_infinite_lattice(1., 20., unit)
# Out:
# <img src="data:image/png;base64,..." width="999.7333333333333">

# %% [markdown]
# ## Finite lattices

# %%
plot_finite_lattice(1., 4, unit)
# Out:
# <img src="data:image/png;base64,..." width="999.7333333333333">
# /home/herck/Development/git/BornAgain-tutorial/walter/iff_helpers.py:65: RuntimeWarning: invalid value encountered in true_divide
#   qy = (np.sin(qx*n_points*period/2)/np.sin(qx*period/2))**2 / n_points
